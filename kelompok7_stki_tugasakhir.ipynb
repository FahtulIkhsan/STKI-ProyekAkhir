# %% [markdown]
# <a href="https://colab.research.google.com/github/FahtulIkhsan/STKI-ProyekAkhir/blob/main/kelompok7_stki_tugasakhir.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from google.colab import drive

# %%
drive.mount('/content/drive')
gr = pd.read_csv('/content/drive/MyDrive/Tugas-Tugas/Goodreads.csv')
print(gr)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#     Book_ID                                              Title           ISBN  \
# 0         0                                   The Hunger Games  9780439023481
# 1         1                           The Chronicles of Narnia  9780066238500
# 2         2                                           Twilight  9780316015844
# 3         3  Alice's Adventure in Wonderland & Through the ...  9780451527745
# 4         4                                          Divergent  9780062024039
# 5         5                                  Lord of the Flies  9780140283334
# 6         6                                           The Help  9780399155345
# 7         7                                      The Alchemist  9780062315007
# 8         8                                    Of Mice and Men  9780142000670
# ...

# %%
nltk.download('stopwords')

regexp = RegexpTokenizer('\w+')
ps = PorterStemmer()

# Make a list of english stopwords
stopwords = nltk.corpus.stopwords.words("english")

# Extend the list with your own custom stopwords
my_stopwords = ['https']
stopwords.extend(my_stopwords)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def preProcess(dataframe) :
  dataframe = dataframe.astype(str).str.lower()
  dataframe = dataframe.apply(regexp.tokenize)
  dataframe = dataframe.apply(lambda x: ' '.join([word for word in x if word not in (stopwords)]))
  dataframe = dataframe.apply(lambda x: ' '.join([ps.stem(word) for word in x.split()]))

  return dataframe

for column in gr :
  gr[column] = preProcess(gr[column])

# %%
#https://github.com/utahta/pyvbcode

from __future__ import division 
from struct import pack, unpack

def encode_number(number):
    """Variable byte code encode number.
    Usage:
      import vbcode
      vbcode.encode_number(128)
    """
    bytes_list = []
    while True:
        bytes_list.insert(0, number % 128)
        if number < 128:
            break
        number = number // 128
    bytes_list[-1] += 128
    return pack('%dB' % len(bytes_list), *bytes_list)

def encode(numbers):
    """Variable byte code encode numbers.
    Usage:
      import vbcode
      vbcode.encode([32, 64, 128])
    """
    bytes_list = []
    for number in numbers:
        bytes_list.append(encode_number(number))
    return b"".join(bytes_list)

def decode(bytestream):
    """Variable byte code decode.
    Usage:
      import vbcode
      vbcode.decode(bytestream)
        -> [32, 64, 128]
    """
    n = 0
    numbers = []
    bytestream = unpack('%dB' % len(bytestream), bytestream)
    for byte in bytestream:
        if byte < 128:
            n = 128 * n + byte
        else:
            n = 128 * n + (byte - 128)
            numbers.append(n)
            n = 0
    return numbers

# %%
import sys
import psutil
import json
from collections import OrderedDict

def indexing(dictionary, documents):
  mem = psutil.virtual_memory()
  i = 0
  
  while(mem.available > 0 and i < len(documents)):
    row = documents.iloc[i]
    if type(row) is not str :
      row = str(row)
    tokens = row.split()
    for token in tokens:
      if token not in dictionary:
        dictionary[token] = []
      if i not in dictionary[token]:
        dictionary[token].append(i)
    i = i + 1
  
  for values in dictionary.values() :
    values.sort()
  dictionary = OrderedDict(sorted(dictionary.items()))
  return dictionary

def compressIndex(dictionary) :
  # with open("./output.txt", "w") as text_file:
  #   text_file.write(json.dumps(dictionary))
  
  with open("./posting_list.bin", "wb") as binary_file, open("./dictionary.txt", "w") as dict_file :
    for i, posting_list in dictionary.items() :
      binary_file.write(encode(posting_list))
      # dict_term = str(i)+"<"+str(binary_file.tell())+">"
      # dict_file.write(dict_term)
      dictionary[i] = binary_file.tell()
    dict_file.write(json.dumps(dictionary))

  return dictionary

invertedIndex = {}
for column in gr :
  invertedIndex = indexing(invertedIndex, gr[column])
print(invertedIndex)

invertedIndex = compressIndex(invertedIndex)
print(invertedIndex)
# Out:
# OrderedDict([('0', [0]), ('04', [39]), ('1', [1, 3, 5, 8, 11, 23, 24, 26, 27, 31, 37, 42]), ('10', [6, 10, 42]), ('100', [22]), ('11', [11, 42]), ('12', [9, 12, 18]), ('13', [13]), ('14', [0, 14, 39]), ('15', [7, 15, 25]), ('16', [16, 17, 20, 32, 42]), ('17', [13, 17]), ('18', [18]), ('1811', [22]), ('1821', [22]), ('19', [19]), ('1910', [26]), ('1911', [26]), ('1912', [12]), ('1930', [8]), ('1931', [11]), ('1932', [11]), ('1937', [8]), ('1949', [1]), ('1962', [6]), ('1986', [9]), ('1998', [11, 26]), ('1999', [5]), ('2', [2, 19, 21, 33, 42]), ('20', [20]), ('2000', [3, 27]), ('2001', [31]), ('2002', [8]), ('2003', [25]), ('2004', [47]), ('2006', [2]), ('2007', [24]), ('2008', [0]), ('2009', [6]), ('2012', [4, 40, 44]), ('2013', [10]), ('2014', [1, 7, 41]), ('2016', [42]), ('2019', [23, 33, 35, 49]), ('2020', [13, 38, 39, 43]), ('2021', [14, 36, 37, 45, 46, 48, 50]), ('2022', [12, 15, 16, 17, 18, 19, 20, 21, 22, 28, 29, 30, 32, 34]), ('21', [21]), ('22', [22]), ('23', [10, 23]), ('236
# ...

# %%
import numpy as np

def term_document_matrix(td_matrix, documents):
  i = 0
  while(i < len(documents)):
    row = documents.iloc[i]
    if type(row) is not str:
      row = str(row)
    tokens = row.split()
    for token in tokens:
      td_matrix.loc[token, i] += 1
    i = i + 1

  return td_matrix

def tf_idf_matrix(td_matrix):
  total_doc = len(gr)
  document_frequency = td_matrix.sum(axis=1)
  inverse_document_frequency = np.log2(total_doc/document_frequency)
  tf_idf = td_matrix.copy()

  for term in td_matrix.index.values:
    for doc in td_matrix.columns.values:
      tf_idf.loc[term, doc] = td_matrix.loc[term, doc] * inverse_document_frequency[term]
  
  return tf_idf

td_matrix = pd.DataFrame(columns=gr.index.tolist(), index=invertedIndex.keys()).fillna(0)
for column in gr :
  td_matrix = term_document_matrix(td_matrix, gr[column])

tf_idf_matrix = tf_idf_matrix(td_matrix)
print(tf_idf_matrix)
# Out:
#                 0         1    2         3    4         5         6    7   \
# 0         5.672425  0.000000  0.0  0.000000  0.0  0.000000  0.000000  0.0
# 04        0.000000  0.000000  0.0  0.000000  0.0  0.000000  0.000000  0.0
# 1         0.000000  3.531069  0.0  1.765535  0.0  1.765535  0.000000  0.0
# 10        0.000000  0.000000  0.0  0.000000  0.0  0.000000  4.087463  0.0
# 100       0.000000  0.000000  0.0  0.000000  0.0  0.000000  0.000000  0.0
# ...            ...       ...  ...       ...  ...       ...       ...  ...
# younwiti  0.000000  0.000000  0.0  0.000000  0.0  0.000000  0.000000  0.0
# zenith    0.000000  0.000000  0.0  0.000000  0.0  0.000000  0.000000  0.0
# zoey      0.000000  0.000000  0.0  0.000000  0.0  0.000000  0.000000  0.0
# zola      0.000000  0.000000  0.0  0.000000  0.0  0.000000  0.000000  0.0
# zone      0.000000  0.000000  0.0  0.000000  0.0  0.000000  0.000000  0.0
#
#                 8    9   ...   41        42   43   44   45   46   47   48  \
# ...

# %%
import math

def doc_cosine_similarity(doc1, doc2, tf_idf_matrix):
  document1 = tf_idf_matrix.loc[:,doc1].tolist()
  document2 = tf_idf_matrix.loc[:,doc2].tolist()

  dot_product =  np.dot(document1, document2)

  magnitude1 = math.sqrt(sum(i**2 for i in document1))
  magnitude2 = math.sqrt(sum(i**2 for i in document2))
  cross_product = magnitude1*magnitude2

  cosine_similarity = dot_product/cross_product

  return cosine_similarity

def cosine_similarity_matrix(tf_idf_matrix):
  cos_sim_matrix = pd.DataFrame(columns=tf_idf_matrix.columns.values, index=tf_idf_matrix.columns.values).fillna(0)

  for row in cos_sim_matrix.index.values:
    for column in cos_sim_matrix.columns.values:
      cos_sim_matrix.loc[row, column] = doc_cosine_similarity(row, column, tf_idf_matrix)
  
  return cos_sim_matrix

#cos_sim_matrix = cosine_similarity_matrix(tf_idf_matrix)

# %%
def getList(term) :
  # prepare additional dictionaries
  ki = dict()
  ik = dict()
  for i, k in enumerate(invertedIndex):
    ki[k] = i   # dictionary index_of_key
    ik[i] = k   # dictionary key_of_index
 
  # initializing key and offset
  current_key = term
  offset = 1  # (1 for next key, but can be any existing distance)
 
  # Get previous key in Dictionary and read length
  pos_before = 0
  if term in ki :
    index_of_current_key = ki[term]
    index_of_previous_key = index_of_current_key - offset
    term_before = ik[index_of_previous_key] if index_of_previous_key in ik else None

    pos = invertedIndex[term]
    if term_before is not None :
      pos_before = invertedIndex[term_before]
      read_len = pos - pos_before
    else :
      pos_before = pos
      read_len = 1
  else :
    read_len = 0

  #Get list from posting lists file
  with open("posting_list.bin", "rb") as binary_file :
    binary_file.seek(pos_before)
    encoded = binary_file.read(read_len)
    decoded = decode(encoded)
  
  return decoded

# %%
def intersection(lst1, lst2):
  lst3 = [value for value in lst1 if value in lst2]
  return lst3
  
def queryProcess(query) :
  query = query.lower()
  query = regexp.tokenize(query)
  query = [word for word in query if word not in stopwords]
  query = [ps.stem(word) for word in query if word not in stopwords]
  if not query :
    intersect_list = query
  else :
    intersect_list = getList(query[0])
    for word in query :
      current_list = getList(word)
      intersect_list = intersection(intersect_list, current_list)

  rank = {}

  querydf = td_matrix[intersect_list]
  querydf.loc[:, 'query'] = 0
  for word in query:
    querydf.loc[word, 'query'] += 1
  
  total_doc = len(querydf.columns)
  document_frequency = querydf.sum(axis=1)
  inverse_document_frequency = np.log2(total_doc/(document_frequency + 1))

  querytf_idf = querydf.copy()

  for term in querydf.index.values:
    for doc in querydf.columns.values:
      querytf_idf.loc[term, doc] = querydf.loc[term, doc] * inverse_document_frequency[term]

  for doc in intersect_list :
    score = doc_cosine_similarity('query', doc, querytf_idf)
    rank[score] = doc

  rank = OrderedDict(sorted(rank.items(), reverse = True))
  result = list(rank.values())

  return result

# %%
query = input("Insert Query : ")
result = queryProcess(query)
print(result)
# Out:
# Insert Query : Computer Science
# [40, 43, 38, 42, 39, 44, 50, 36]
